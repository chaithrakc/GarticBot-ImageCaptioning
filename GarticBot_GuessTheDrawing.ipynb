# %% [markdown]
# # Gartic Bot - Guess the Drawing
#
# **Author:** Chaithra K C<br>
# **Date created:** May 17, 2022<br>
# **Last modified:** May 22, 2022<br>
# **Description:** Training the model to generate image captions
